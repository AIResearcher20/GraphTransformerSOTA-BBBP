# %% [markdown]
# # 🧠 GraphTransformerSOTA-BBBP
# ## Hybrid GIN-Transformer for Blood-Brain Barrier Penetration Prediction
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/yourusername/GraphTransformerSOTA-BBBP/blob/main/notebooks/bbbp_training.ipynb)
#
# ---

# %% [markdown]
# ## 📦 1. Install Dependencies

# %%
# Install required libraries
# !pip install torch torch-geometric rdkit-pypi scikit-learn matplotlib seaborn pyyaml tqdm -q

print("✅ All dependencies installed!")

# %% [markdown]
# ## 📂 2. Clone Repository & Setup

# %%
# Clone the repository (or mount Google Drive)
# !git clone https://github.com/yourusername/GraphTransformerSOTA-BBBP.git /content/GraphTransformerSOTA-BBBP
# !cd /content/GraphTransformerSOTA-BBBP

import sys
sys.path.append('/content/GraphTransformerSOTA-BBBP')

print("✅ Repository cloned!")

# %% [markdown]
# ## 🚀 3. Run Full Experiment

# %%
# !cd /content/GraphTransformerSOTA-BBBP && python scripts/run_experiment.py

# %% [markdown]
# ## 📊 4. Download Results

# %%
from google.colab import files
import os

results_dir = '/content/GraphTransformerSOTA-BBBP/results'
files_to_download = ['best_model.pt', 'training_history.png', 'baseline_comparison.csv', 'tox21_result.txt']

for f in files_to_download:
    path = os.path.join(results_dir, f)
    if os.path.exists(path):
        files.download(path)
        print(f"✅ {f} downloaded")
    else:
        print(f"⚠️ {f} not found")

# %% [markdown]
# ## 📚 5. Citation
#
# If you use this work, please cite:
#
# ```bibtex
# @software{karimi2026graphtransformer,
#   author = {Karimi, Vania},
#   title = {GraphTransformerSOTA-BBBP: Hybrid GIN-Transformer for BBB Prediction},
#   year = {2026},
#   url = {https://github.com/yourusername/GraphTransformerSOTA-BBBP}
# }
# ```
